# %%
import pandas as pd
import numpy as np

# %%
df_meteorites = pd.read_csv('./db/Meteorite_Landings.csv')

# %%
df_meteorites.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
df_meteorites.tail(10)
# Out:
#              name     id nametype              recclass   mass (g)   fall  \
# 45706     Zerkaly  31354    Valid                    H5    16000.0  Found
# 45707    Zhaoping  54609    Valid     Iron, IAB complex  2000000.0  Found
# 45708    Zhigansk  30405    Valid           Iron, IIIAB   900000.0  Found
# 45709  Zhongxiang  30406    Valid                  Iron   100000.0  Found
# 45710  Zillah 001  31355    Valid                    L6     1475.0  Found
# 45711  Zillah 002  31356    Valid               Eucrite      172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46.0  Found
# 45713        Zlin  30410    Valid                    H4        3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45706  01/01/1956 12:00:00 AM  52.13333   81.96667    (52.13333, 81.96667)
# ...

# %%
df_meteorites.sample(10)
# Out:
#                               name     id nametype recclass  mass (g)   fall  \
# 34807  Queen Alexandra Range 99176  21627    Valid      LL5     27.40  Found
# 34733  Queen Alexandra Range 99101  21553    Valid      LL5     13.80  Found
# 26469         Northwest Africa 060  17070    Valid      CK5    604.00  Found
# 5067                       Beenham   4995    Valid       L5  44400.00  Found
# 28670        Northwest Africa 4441  45446    Valid    CO3.2    124.00  Found
# 12881        Graves Nunataks 98075  11067    Valid       H5     20.60  Found
# 42378                 Yamato 81023  29084    Valid      CO3      9.58  Found
# 10625       Elephant Moraine 90610   9019    Valid       L6   1450.80  Found
# 26254           Mount Walton 01001  16807    Valid     H4/5    271.60  Found
# 29286        Northwest Africa 5302  48928    Valid       L5     46.20  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
df_meteorites.shape
# Out:
# (45716, 10)

# %%
df_meteorites.size
# Out:
# 457160

# %%
df_meteorites.describe()
# Out:
#                  id      mass (g)        reclat       reclong
# count  45716.000000  4.558500e+04  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04    -39.122580     61.074319
# std    16860.683030  5.749889e+05     46.378511     80.647298
# min        1.000000  0.000000e+00    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02      0.000000    157.166670
# max    57458.000000  6.000000e+07     81.166670    354.473330

# %%
pd.options.display.float_format = '{:,.1f}'.format

# %%
df_meteorites.describe()
# Out:
#             id     mass (g)   reclat  reclong
# count 45,716.0     45,585.0 38,401.0 38,401.0
# mean  26,889.7     13,278.1    -39.1     61.1
# std   16,860.7    574,988.9     46.4     80.6
# min        1.0          0.0    -87.4   -165.4
# 25%   12,688.8          7.2    -76.7      0.0
# 50%   24,261.5         32.6    -71.5     35.7
# 75%   40,656.8        202.6      0.0    157.2
# max   57,458.0 60,000,000.0     81.2    354.5

# %%
df_meteorites.describe(include='all')
# Out:
#                  name       id nametype recclass     mass (g)   fall  \
# count           45716 45,716.0    45716    45716     45,585.0  45716
# unique          45716      nan        2      466          nan      2
# top     Yamato 981133      nan    Valid       L6          nan  Found
# freq                1      nan    45641     8285          nan  44609
# mean              NaN 26,889.7      NaN      NaN     13,278.1    NaN
# std               NaN 16,860.7      NaN      NaN    574,988.9    NaN
# min               NaN      1.0      NaN      NaN          0.0    NaN
# 25%               NaN 12,688.8      NaN      NaN          7.2    NaN
# 50%               NaN 24,261.5      NaN      NaN         32.6    NaN
# 75%               NaN 40,656.8      NaN      NaN        202.6    NaN
# max               NaN 57,458.0      NaN      NaN 60,000,000.0    NaN
#
#                           year   reclat  reclong GeoLocation
# count                    45425 38,401.0 38,401.0       38401
# ...

# %%
df_meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
df_meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df_meteorites.convert_dtypes().dtypes # Convertir el tipo de dato de los campos
# Out:
# name            string
# id               Int64
# nametype        string
# recclass        string
# mass (g)       float64
# fall            string
# year            string
# reclat         float64
# reclong        float64
# GeoLocation     string
# dtype: object

# %%
df_meteorites.nunique() # variabilidad de los campos
# Out:
# name           45716
# id             45716
# nametype           2
# recclass         466
# mass (g)       12576
# fall               2
# year             266
# reclat         12738
# reclong        14640
# GeoLocation    17100
# dtype: int64

# %%
df_meteorites[['fall', 'nametype']] # Variables categoricas
# Out:
#         fall nametype
# 0       Fell    Valid
# 1       Fell    Valid
# 2       Fell    Valid
# 3       Fell    Valid
# 4       Fell    Valid
# ...      ...      ...
# 45711  Found    Valid
# 45712  Found    Valid
# 45713  Found    Valid
# 45714  Found    Valid
# 45715  Found    Valid
#
# [45716 rows x 2 columns]

# %%
df_meteorites[['fall', 'nametype']] = df_meteorites[['fall', 'nametype']].astype('category') # Convertir a varaibles categoricas

# %%
df_meteorites.dtypes
# Out:
# name             object
# id                int64
# nametype       category
# recclass         object
# mass (g)        float64
# fall           category
# year             object
# reclat          float64
# reclong         float64
# GeoLocation      object
# dtype: object

# %%
df_meteorites['fall'].unique()
# Out:
# [Fell, Found]
# Categories (2, object): [Fell, Found]

# %%
df_meteorites['fall'].value_counts() # Frecuencia
# Out:
# Found    44609
# Fell      1107
# Name: fall, dtype: int64

# %%
# Variables dummis
pd.get_dummies(df_meteorites['fall'])
# Out:
#        Fell  Found
# 0         1      0
# 1         1      0
# 2         1      0
# 3         1      0
# 4         1      0
# ...     ...    ...
# 45711     0      1
# 45712     0      1
# 45713     0      1
# 45714     0      1
# 45715     0      1
#
# [45716 rows x 2 columns]

# %%
# Crear columnas
df_meteorites[['fell', 'found']] = pd.get_dummies(df_meteorites['fall'])
df_meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year  reclat  reclong             GeoLocation  fell  \
# ...

# %%
df_meteorites['year']
# Out:
# 0        01/01/1880 12:00:00 AM
# 1        01/01/1951 12:00:00 AM
# 2        01/01/1952 12:00:00 AM
# 3        01/01/1976 12:00:00 AM
# 4        01/01/1902 12:00:00 AM
#                   ...
# 45711    01/01/1990 12:00:00 AM
# 45712    01/01/1999 12:00:00 AM
# 45713    01/01/1939 12:00:00 AM
# 45714    01/01/2003 12:00:00 AM
# 45715    01/01/1976 12:00:00 AM
# Name: year, Length: 45716, dtype: object

# %%
# Transformar 'year' a una variable tipo tiempo
pd.to_datetime(
    df_meteorites['year'],
    errors = 'coerce',
    format='%m/%d/%Y %H:%M:%S %p'
)
# Out:
# 0       1880-01-01 12:00:00
# 1       1951-01-01 12:00:00
# 2       1952-01-01 12:00:00
# 3       1976-01-01 12:00:00
# 4       1902-01-01 12:00:00
#                 ...
# 45711   1990-01-01 12:00:00
# 45712   1999-01-01 12:00:00
# 45713   1939-01-01 12:00:00
# 45714   2003-01-01 12:00:00
# 45715   1976-01-01 12:00:00
# Name: year, Length: 45716, dtype: datetime64[ns]

# %%
df_meteorites['year'] = pd.to_datetime(
    df_meteorites['year'],
    errors = 'coerce',
    format='%m/%d/%Y %H:%M:%S %p'
)

# %%
df_meteorites.convert_dtypes().dtypes
# Out:
# name                   string
# id                      Int64
# nametype             category
# recclass               string
# mass (g)              float64
# fall                 category
# year           datetime64[ns]
# reclat                float64
# reclong               float64
# GeoLocation            string
# fell                    UInt8
# found                   UInt8
# dtype: object

# %%
# Renombrar columnas
df_meteorites.rename(columns={'mass (g)': 'mass'}, inplace=True)

# %%
df_meteorites
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...

# %%
list(df_meteorites)
# Out:
# ['name',
#  'id',
#  'nametype',
#  'recclass',
#  'mass',
#  'fall',
#  'year',
#  'reclat',
#  'reclong',
#  'GeoLocation',
#  'fell',
#  'found']

# %%
df_meteorites['ones'] = np.ones(len(df_meteorites))

# %%
df_meteorites
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...

# %%
# Eliminar columnas
df_meteorites.drop(['ones'], axis=1, inplace= True) # Inplace registra el cambio

# %%
df_meteorites
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...

# %%
# Eliminar filas
df_meteorites.drop([0, 2, 4, 6]).head(10)
# Out:
#                 name   id nametype      recclass     mass  fall  \
# 1             Aarhus    2    Valid            H6    720.0  Fell
# 3           Acapulco   10    Valid   Acapulcoite  1,914.0  Fell
# 5           Adhi Kot  379    Valid           EH4  4,239.0  Fell
# 7               Agen  392    Valid            H5 30,000.0  Fell
# 8             Aguada  398    Valid            L6  1,620.0  Fell
# 9      Aguila Blanca  417    Valid             L  1,440.0  Fell
# 10  Aioun el Atrouss  423    Valid  Diogenite-pm  1,000.0  Fell
# 11               Aïr  424    Valid            L6 24,000.0  Fell
# 12   Aire-sur-la-Lys  425    Valid       Unknown      nan  Fell
# 13             Akaba  426    Valid            L6    779.0  Fell
#
#                   year  reclat  reclong           GeoLocation  fell  found
# 1  1951-01-01 12:00:00    56.2     10.2  (56.18333, 10.23333)     1      0
# 3  1976-01-01 12:00:00    16.9    -99.9     (16.88333, -99.9)     1      0
# ...

# %%
df_meteorites.drop(columns=['id', 'recclass'], index = [1, 3, 5, 7]).head(10)
# Out:
#                    name nametype      mass  fall                year  reclat  \
# 0                Aachen    Valid      21.0  Fell 1880-01-01 12:00:00    50.8
# 2                  Abee    Valid 107,000.0  Fell 1952-01-01 12:00:00    54.2
# 4               Achiras    Valid     780.0  Fell 1902-01-01 12:00:00   -33.2
# 6   Adzhi-Bogdo (stone)    Valid     910.0  Fell 1949-01-01 12:00:00    44.8
# 8                Aguada    Valid   1,620.0  Fell 1930-01-01 12:00:00   -31.6
# 9         Aguila Blanca    Valid   1,440.0  Fell 1920-01-01 12:00:00   -30.9
# 10     Aioun el Atrouss    Valid   1,000.0  Fell 1974-01-01 12:00:00    16.4
# 11                  Aïr    Valid  24,000.0  Fell 1925-01-01 12:00:00    19.1
# 12      Aire-sur-la-Lys    Valid       nan  Fell 1769-01-01 12:00:00    50.7
# 13                Akaba    Valid     779.0  Fell 1949-01-01 12:00:00    29.5
#
#     reclong           GeoLocation  fell  found
# 0       6.1     (50.775, 6.08333)     1      0
# ...

# %%
# Crear una copia que no afecte el dataframe
df = df_meteorites.copy(deep= True)
df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df
# Out:
#              name nametype              recclass      mass   fall  \
# 0          Aachen    Valid                    L5      21.0   Fell
# 1          Aarhus    Valid                    H6     720.0   Fell
# 2            Abee    Valid                   EH4 107,000.0   Fell
# 3        Acapulco    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    Valid                    L6     780.0   Fell
# ...           ...      ...                   ...       ...    ...
# 45711  Zillah 002    Valid               Eucrite     172.0  Found
# 45712      Zinder    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin    Valid                    H4       3.3  Found
# 45714   Zubkovsky    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# 0     1880-01-01 12:00:00    50.8      6.1       (50.775, 6.08333)     1
# ...

# %%
df_meteorites
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4 107,000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite   1,914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6   2,167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                      year  reclat  reclong             GeoLocation  fell  \
# ...
