# %%
import pandas as pd
import numpy as np

# %%
df_left = pd.DataFrame(
    {'X':['x0','x1','x2','x3'],
    'W':['w0','w1','w2','w3'],
    'Y':['y0','y1','y2','y3'],
    'Mix':['y2','y3','a2','a3']},
    index = [0, 1, 2, 3])

df_left
# Out:
#     X   W   Y Mix
# 0  x0  w0  y0  y2
# 1  x1  w1  y1  y3
# 2  x2  w2  y2  a2
# 3  x3  w3  y3  a3

# %%
df_right = pd.DataFrame(
    {'Z':['z2','z3','z4','z5'],
     'A':['a2','a3','a4','a5'],
     'Y':['y2','y3','y4','y5']},
    index = [2, 3, 4, 5])

df_right
# Out:
#     Z   A   Y
# 2  z2  a2  y2
# 3  z3  a3  y3
# 4  z4  a4  y4
# 5  z5  a5  y5

# %%
pd.merge(df_left, df_right)
# Out:
#     X   W   Y Mix   Z   A
# 0  x2  w2  y2  a2  z2  a2
# 1  x3  w3  y3  a3  z3  a3

# %%
pd.merge(df_left, df_right, how='inner', on='Y')
# Out:
#     X   W   Y Mix   Z   A
# 0  x2  w2  y2  a2  z2  a2
# 1  x3  w3  y3  a3  z3  a3

# %%
pd.merge(df_left, df_right, how='inner', left_on='Mix', right_on='Y')
# Out:
#     X   W Y_x Mix   Z   A Y_y
# 0  x0  w0  y0  y2  z2  a2  y2
# 1  x1  w1  y1  y3  z3  a3  y3

# %%
pd.merge(df_left, df_right, how='inner', left_on='Mix', right_on='A')
# Out:
#     X   W Y_x Mix   Z   A Y_y
# 0  x2  w2  y2  a2  z2  a2  y2
# 1  x3  w3  y3  a3  z3  a3  y3

# %% [markdown]
# ![](http://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png)

# %%
pd.merge(df_left, df_right, how='left', on='Y')
# Out:
#     X   W   Y Mix    Z    A
# 0  x0  w0  y0  y2  NaN  NaN
# 1  x1  w1  y1  y3  NaN  NaN
# 2  x2  w2  y2  a2   z2   a2
# 3  x3  w3  y3  a3   z3   a3

# %%
pd.merge(df_left, df_right, how='right', on='Y')
# Out:
#      X    W   Y  Mix   Z   A
# 0   x2   w2  y2   a2  z2  a2
# 1   x3   w3  y3   a3  z3  a3
# 2  NaN  NaN  y4  NaN  z4  a4
# 3  NaN  NaN  y5  NaN  z5  a5

# %%
pd.merge(df_left, df_right, how='outer', on='Y')
# Out:
#      X    W   Y  Mix    Z    A
# 0   x0   w0  y0   y2  NaN  NaN
# 1   x1   w1  y1   y3  NaN  NaN
# 2   x2   w2  y2   a2   z2   a2
# 3   x3   w3  y3   a3   z3   a3
# 4  NaN  NaN  y4  NaN   z4   a4
# 5  NaN  NaN  y5  NaN   z5   a5

# %%
df_left = pd.DataFrame(
    {'X':['x0','x1','x2','x3'],
    'W':['w0','w1','w2','w3'],
    'Y':['y0','y1','y2','y3'],
    'A':['a0','a1','a2','a3']},
    index = [0, 1, 2, 3])

df_left
# Out:
#     X   W   Y   A
# 0  x0  w0  y0  a0
# 1  x1  w1  y1  a1
# 2  x2  w2  y2  a2
# 3  x3  w3  y3  a3

# %%
df_right
# Out:
#     Z   A   Y
# 2  z2  a2  y2
# 3  z3  a3  y3
# 4  z4  a4  y4
# 5  z5  a5  y5

# %%
pd.merge(df_left, df_right, how='outer', on=['Y', 'A'])
# Out:
#      X    W   Y   A    Z
# 0   x0   w0  y0  a0  NaN
# 1   x1   w1  y1  a1  NaN
# 2   x2   w2  y2  a2   z2
# 3   x3   w3  y3  a3   z3
# 4  NaN  NaN  y4  a4   z4
# 5  NaN  NaN  y5  a5   z5

# %%
pd.merge(df_left, df_right, how='outer', on='A', suffixes=['_left', '_right'])
# Out:
#      X    W Y_left   A    Z Y_right
# 0   x0   w0     y0  a0  NaN     NaN
# 1   x1   w1     y1  a1  NaN     NaN
# 2   x2   w2     y2  a2   z2      y2
# 3   x3   w3     y3  a3   z3      y3
# 4  NaN  NaN    NaN  a4   z4      y4
# 5  NaN  NaN    NaN  a5   z5      y5

# %%
df_merge_r = pd.merge(df_left, df_right, how='right', on='Y')
df_merge_r[df_merge_r['X', 'W', 'A_x'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('X', 'W', 'A_x')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-9bc97d5beb09> in <module>
#       1 df_merge_r = pd.merge(df_left, df_right, how='right', on='Y')
# ----> 2 df_merge_r[df_merge_r['X', 'W', 'A_x'].notnull()]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('X', 'W', 'A_x')

# %%
pd.merge(df_left, df_right, how='right', on='Y')
# Out:
#      X    W   Y  A_x   Z A_y
# 0   x2   w2  y2   a2  z2  a2
# 1   x3   w3  y3   a3  z3  a3
# 2  NaN  NaN  y4  NaN  z4  a4
# 3  NaN  NaN  y5  NaN  z5  a5
